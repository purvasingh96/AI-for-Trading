# %% [markdown]
# <a id="table_of_content"></a>

# %% [markdown]
# # Part 1: Bag-of-Words Exercises
#
# In the following, we will convert our corpus of 10-k documents into bag-of-words, and convert them into document vectors using Term-Frequency-Inverse-Document-Frequency (tf-idf) re-weighting. Afterward, we will compute sentiments and similarity metrics. Since we will be reusing our notebook, so the various sections are linked below:
#
# 1. <a href="#bag_of_word">Compute bag-of-words </a>: implement `bag_of_words` that converts tokenized words into a dictionary of word-counts
#
# 2. <a href="#sentiment">Sentiments </a>: using wordlists, compute positive and negative sentiments from bag-of-words. Implement `get_sentiment`
#
# For solutions, see [bagofwords_solutions.py](./bagofwords_solutions.py). You can load the functions by simply calling
#
# `from bagofwords_solutions import *`
#
# # Part 2: Document-Vector Exercises
#
# 3. <a href="#compute_idf">Compute idf </a>: computing the inverse document frequency, implement `get_idf`
#
# 4. <a href="#compute_tf">Compute tf </a>: computing the term frequency, implement `get_tf`
#
# 5. <a href="#doc_vector">Document vector </a>: using the functions `get_idf` and `get_tf`, compute a word_vector for each document in the corpus
# 6. <a href="#similarity">Similarities </a>: comparing two vectors, and compute cosine and jacard similarity metrics. Implement `get_cos` and `get_jac`
#
# For solutions, see [bagofwords_solutions.py](./bagofwords_solutions.py). You can load the functions by simply calling
#
# `from bagofwords_solutions import *`

# %% [markdown]
# ## 0. Initialization
#
# First we read in our 10-k documents

# %%
# download some excerpts from 10-K files
from download10k import get_files

CIK = {'ebay': '0001065088', 'apple':'0000320193', 'sears': '0001310067'}
get_files(CIK['ebay'], 'EBAY')
get_files(CIK['apple'], 'AAPL')
get_files(CIK['sears'], 'SHLDQ')


# get a list of all 10-ks in our directory
files=! ls *10k*.txt
print("10-k files: ",files)
files = [open(f,"r").read() for f in files]
# Out:
# downloading 10-Ks item 1A for CIK = 0001065088 ...
# skipping EBAY_10k_2017.txt
# skipping EBAY_10k_2016.txt
# skipping EBAY_10k_2015.txt
# skipping EBAY_10k_2014.txt
# skipping EBAY_10k_2013.txt
# downloading 10-Ks item 1A for CIK = 0000320193 ...
# skipping AAPL_10k_2017.txt
# skipping AAPL_10k_2016.txt
# skipping AAPL_10k_2015.txt
# skipping AAPL_10k_2014.txt
# skipping AAPL_10k_2013.txt
# downloading 10-Ks item 1A for CIK = 0001310067 ...
# skipping SHLDQ_10k_2017.txt
# skipping SHLDQ_10k_2016.txt
# skipping SHLDQ_10k_2015.txt
# skipping SHLDQ_10k_2014.txt
# skipping SHLDQ_10k_2013.txt
# 10-k files:  ['AAPL_10k_2013.txt', 'AAPL_10k_2014.txt', 'AAPL_10k_2015.txt', 'AAPL_10k_2016.txt', 'AAPL_10k_2017.txt', 'EBAY_10k_2013.txt', 'EBAY_10k_2014.txt', 'EBAY_10k_2015.txt', 'EBAY_10k_2016.txt', 'EBAY_10k_2017.txt', 'SHLDQ_10k_2013.txt', 'SHLDQ_10k_2014.txt', 'SHLDQ_10k_2015.txt', 'SHLDQ_10k_2016.txt', 'SHLDQ_10k_2017.txt']

# %% [markdown]
# here we define useful functions to tokenize the texts into words, remove stop-words, and lemmatize and stem our words

# %%
import numpy as np

# for nice number printing
np.set_printoptions(precision=3, suppress=True)

# tokenize and clean the text
import nltk
from nltk.stem import WordNetLemmatizer, SnowballStemmer
from collections import Counter
from nltk.corpus import stopwords
from nltk import word_tokenize
from nltk.tokenize import RegexpTokenizer
# tokenize anything that is not a number and not a symbol
word_tokenizer = RegexpTokenizer(r'[^\d\W]+')

nltk.download('stopwords')
nltk.download('wordnet')


sno = SnowballStemmer('english')
wnl = WordNetLemmatizer()

# get our list of stop_words
nltk.download('stopwords')
stop_words = set(stopwords.words('english')) 
# add some extra stopwords
stop_words |= {"may", "business", "company", "could", "service", "result", "product", 
               "operation", "include", "law", "tax", "change", "financial", "require",
               "cost", "market", "also", "user", "plan", "actual", "cash", "other",
               "thereto", "thereof", "therefore"}

# useful function to print a dictionary sorted by value (largest first by default)
def print_sorted(d, ascending=False):
    factor = 1 if ascending else -1
    sorted_list = sorted(d.items(), key=lambda v: factor*v[1])
    for i, v in sorted_list:
        print("{}: {:.3f}".format(i, v))

# convert text into bag-of-words
def clean_text(txt):
    lemm_txt = [ wnl.lemmatize(wnl.lemmatize(w.lower(),'n'),'v') \
                for w in word_tokenizer.tokenize(txt) if \
                w.isalpha() and w not in stop_words ]
    return [ sno.stem(w) for w in lemm_txt if w not in stop_words and len(w) > 2 ]

corpus = [clean_text(f) for f in files]
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# <a id="bag_of_words"></a>

# %% [markdown]
# ## 1. Bag-of-Words

# %% [markdown]
# Implement a function that converts a list of tokenized words into bag-of-words, i.e. a dictionary that outputs the frequency count of a word
#
# ** python already provide the `collections.Counter` class to perform this, but I encourage you to implement your own function as an exercise
#
# <a href="#table_of_content">back to top</a>

# %%
from collections import defaultdict
from collections import Counter

def bag_of_words(words):
    # TO DO
    count_dict = defaultdict(int)
    for word in words:
        count_dict[word]+=1
    return count_dict

# %% [markdown]
# <a id="sentiment"></a>

# %% [markdown]
# ## 2. Sentiments
# Count the fraction of words that appear in a wordlist, returning a sentiment score between 0 and 1:
#
# $$
# \textrm{score} = \frac{\textrm{Number of words in document matching wordlist}}{\textrm{Number of words in document}}
# $$
#
# Implement the score in a function `get_sentiment(words, wordlist)`, where words is a list of words. Feel free to use the previous `bag_of_words` function.
# (*for extra challenge, try to code the function in one-line*)
#
# Here, I've included a positive and negative wordlist that I constructed by hand. Due to copyright issues, we are not able to provide other commonly used wordlists. I encourage you to try out different wordlists on your own.
#
# <a href="#table_of_content">back to top</a>

# %%
# load wordlist first
import pickle

with open('positive_words.pickle', 'rb') as f:
    positive_words = pickle.load(f)
    # also need to stem and lemmatize the text
    positive_words = set(clean_text(" ".join(positive_words)))
    
with open('negative_words.pickle', 'rb') as f:
    negative_words = pickle.load(f)
    negative_words = set(clean_text(" ".join(negative_words)))
    
# check out the list
print("positive words: ", positive_words)
print("negative words: ", negative_words)
# Out:
# positive words:  {'bright', 'solut', 'celebr', 'miracul', 'best', 'except', 'revolutionari', 'stabil', 'resolv', 'fortun', 'perfect', 'beauti', 'congratul', 'creativ', 'eleg', 'visionari', 'clear', 'astonish', 'popular', 'flourish', 'applaus', 'trendi', 'famous', 'victori', 'nurtur', 'glamor', 'higher', 'innov', 'abund', 'wholesom', 'happi', 'command', 'prosper', 'achiev', 'excel', 'approv', 'satisfi', 'surpass', 'paradis', 'special', 'heal', 'improv', 'recov', 'love', 'aptitud', 'enrich', 'persever', 'boost', 'clean', 'effici', 'boon', 'stupend', 'outperform', 'dazzl', 'booster', 'progress', 'bolster', 'fresh', 'master', 'resourc', 'groundbreak', 'spring', 'delight', 'effect', 'dynam', 'harmoni', 'motiv', 'restor', 'honor', 'plenti', 'winner', 'reward', 'divin', 'benign', 'enhanc', 'optim', 'respect', 'monument', 'advanc', 'buoy', 'elev', 'revolution', 'attract', 'forefront', 'magic', 'independ', 'jubil', 'wealth', 'awesom', 'prais', 'compliment', 'fabul', 'endors', 'optimist', 'incred', 'reliev', 'nobil', 'insight', 'nobl', 'accept', 'happili', 'courag', 'high', 'nobli', 'prestigi', 'talent', 'amaz', 'gift', 'strong', 'inspir', 'extraordinarili', 'glow', 'nourish', 'appreci', 'promin', 'profici', 'refresh', 'prestig', 'champion', 'generous', 'support', 'outstand', 'upbeat', 'complet', 'exuber', 'posit', 'rich', 'superb', 'bliss', 'earnest', 'fantast', 'impress', 'benefici', 'attain', 'product', 'strength', 'relief', 'wow', 'enchant', 'better', 'acclaim', 'power', 'safe', 'rebound', 'surmount', 'lucrat', 'merit', 'championship', 'encourag', 'ador', 'ingeni', 'satisfactori', 'reinforc', 'admir', 'good', 'appeal', 'revolut', 'wealthi', 'win', 'prodigi', 'accomplish', 'favor', 'benefit', 'gain', 'exemplifi', 'distinct', 'adorn', 'origin', 'transform', 'legendari', 'bless', 'amelior', 'opportun', 'pleasant', 'meritori', 'polish', 'succeed', 'stabl', 'trendili', 'invent', 'exhilar', 'brilliant', 'extraordinari', 'solv', 'award', 'fascin', 'lead', 'brighter', 'loyalti', 'terrif', 'esteem', 'passion', 'belov', 'recoveri', 'enthusiasm', 'great', 'flawless', 'exquisit', 'cheer', 'vibrant', 'miracl', 'wonder', 'devot', 'upstand', 'virtuous', 'actual', 'tremend', 'surg', 'loyal', 'laud', 'marvel', 'distinguish', 'success', 'benevol', 'growth'}
# negative words:  {'uneth', 'repuls', 'crash', 'horribl', 'afflict', 'insan', 'fatal', 'troublesom', 'obsolesc', 'sacrific', 'manipul', 'pollut', 'foul', 'dissolv', 'exacerb', 'underwhelm', 'vile', 'breakabl', 'impeach', 'kill', 'injuri', 'indign', 'desper', 'instabl', 'fruitless', 'shrink', 'wors', 'unfortun', 'ban', 'fault', 'discredit', 'revolt', 'fraudul', 'incid', 'disgust', 'hard', 'burden', 'disqualifi', 'violent', 'downgrad', 'nasti', 'dead', 'inept', 'sacrifici', 'inviabl', 'defiant', 'inconveni', 'deni', 'arrest', 'threat', 'loot', 'misfortun', 'obsolet', 'misappli', 'unproduct', 'unsettl', 'untal', 'lazili', 'unauthor', 'vice', 'disclaim', 'trial', 'unneed', 'disinterest', 'complaint', 'deplet', 'leak', 'unhappi', 'scourg', 'breach', 'fiasco', 'aggrav', 'argu', 'malfunct', 'underperform', 'illeg', 'corrupt', 'storm', 'rot', 'dull', 'gloomi', 'offens', 'imped', 'fright', 'devalu', 'insolv', 'lag', 'plea', 'deprav', 'incap', 'blacklist', 'wreck', 'reject', 'impedi', 'cloudi', 'oppress', 'strain', 'fire', 'erod', 'malic', 'degrad', 'delay', 'repudi', 'invalid', 'falsifi', 'negat', 'harrow', 'close', 'lawsuit', 'drain', 'lack', 'powerless', 'dark', 'unlaw', 'uninspir', 'vilifi', 'upset', 'weak', 'notori', 'abnorm', 'debt', 'ruin', 'unabl', 'vulgar', 'jail', 'panic', 'suspici', 'doom', 'wast', 'abhorr', 'miseri', 'desol', 'dirti', 'indict', 'slow', 'lower', 'penalti', 'obnoxi', 'harm', 'counterfeit', 'illicit', 'defianc', 'renounc', 'overpay', 'depress', 'disqualif', 'wrong', 'ineffici', 'closur', 'worrisom', 'difficult', 'default', 'forfeit', 'null', 'deplor', 'faulti', 'objection', 'strike', 'frustrat', 'handicap', 'halt', 'blow', 'incident', 'accident', 'hostil', 'crisi', 'advers', 'unfruit', 'forgeri', 'recal', 'escal', 'outlaw', 'dirtili', 'exploit', 'hamper', 'crime', 'flaw', 'termin', 'woe', 'boycott', 'odious', 'steal', 'dread', 'hate', 'shutdown', 'fraud', 'disapprov', 'dysfunct', 'inferior', 'disabl', 'usurp', 'crack', 'horror', 'murder', 'antiqu', 'catastroph', 'disast', 'agoni', 'bankruptci', 'complic', 'neglect', 'suspens', 'illiquid', 'harsh', 'pessim', 'unstabl', 'doubt', 'impoverish', 'deter', 'accid', 'deterior', 'hardest', 'apathi', 'unfair', 'gruesom', 'contradict', 'stress', 'convict', 'blame', 'condemn', 'anomali', 'harsher', 'apathet', 'fail', 'conced', 'pressur', 'embezzl', 'subpoena', 'damag', 'abhor', 'imperil', 'perjuri', 'sue', 'unnecessarili', 'attrit', 'avoid', 'insol', 'demot', 'danger', 'repugn', 'difficulti', 'uncontrol', 'unpopular', 'litig', 'critic', 'unwelcom', 'disfavor', 'disadvantag', 'guilt', 'confus', 'intimid', 'peril', 'malign', 'worst', 'ineffect', 'tragedi', 'lie', 'injur', 'doomsday', 'mockeri', 'desist', 'distress', 'dismal', 'bankrupt', 'disturb', 'inabl', 'hurt', 'incompat', 'unfavor', 'bust', 'abandon', 'bribe', 'hazard', 'undermin', 'untrustworthi', 'nuisanc', 'blackmail', 'error', 'shadi', 'hinder', 'postpon', 'scandal', 'eros', 'evil', 'nullifi', 'pessimist', 'atroci', 'impot', 'argument', 'deris', 'suspend', 'rotten', 'abomin', 'gloom', 'cutback', 'uneffect', 'horrid', 'death', 'thieveri', 'discourag', 'wick', 'ugli', 'unattract', 'collud', 'object', 'unnecessari', 'destroy', 'calam', 'decept', 'fals', 'erron', 'horrend', 'ridicul', 'unscrupul', 'violat', 'content', 'troubl', 'aw', 'terribl', 'failur', 'obstruct', 'trivial', 'break', 'cataclysm', 'appal', 'sorrow', 'headach', 'worri', 'plung', 'dampen', 'nastili', 'shame', 'refus', 'imposs', 'thiev', 'ceas', 'nefari', 'urgent', 'unworthi', 'worsen', 'hatr', 'tragic', 'diminish', 'terror', 'weari', 'declin', 'misus', 'turbul', 'unattain', 'retreat', 'weaken', 'sever', 'taint', 'accus', 'disregard', 'low', 'fear', 'delus', 'bottleneck', 'balk', 'excess', 'hardship', 'lazi', 'devast', 'temper', 'guilti', 'distast', 'harder', 'contempt', 'attenu', 'scorn', 'investig', 'empti', 'misappl', 'conflict', 'collus', 'exhaust', 'curs'}

# %%
def get_sentiment(txt, wordlist):
    # TO DO
    matching_words = [w for w in txt if w in wordlist]
    return len(matching_words)/len(txt)

# %%
# test your function
positive_sentiments = np.array([ get_sentiment(c, positive_words) for c in corpus ])
print(positive_sentiments)

negative_sentiments = np.array([ get_sentiment(c, negative_words) for c in corpus ])
print(negative_sentiments)
# Out:
# [ 0.034  0.033  0.032  0.032  0.031  0.034  0.033  0.034  0.031  0.032
#   0.037  0.033  0.037  0.039  0.04 ]
# [ 0.054  0.053  0.052  0.052  0.053  0.051  0.05   0.054  0.061  0.061
#   0.06   0.059  0.058  0.054  0.059]

# %% [markdown]
# **before continuing part 2, go through the lesson material first!**

# %% [markdown]
# <a id="compute_idf"></a>

# %% [markdown]
# # Part 2 Document Vector Exercises
#
# ## 3. Computer idf
# Given a corpus, or a list of bag-of-words, we want to compute for each word $w$, the inverse-document-frequency, or ${\rm idf}(w)$. This can be done in a few steps:
#
# 1. Gather a set of all the words in all the bag-of-words (python set comes in handy, and the union operator `|` is useful here)
#
#
# 2. Loop over each word $w$, and compute ${\rm df}_w$, the number of documents where this word appears at least once. A dictionary is useful for keeping track of ${\rm df}_w$
#
#
# 3. After computing ${\rm df}_w$, we can compute ${\rm idf}(w)$. There are usually two possibilities, the simplest one is
# $${\rm idf}(w)=\frac{N}{{\rm df}_w}$$
# Where $N$ is the total number of documents in the corpus and $df_w$ the number of documents that contain the word $w$. Frequently, a logarithm term is added as well
# $${\rm idf}(w)=\log\frac{N}{{\rm df}_w}$$
# One issue with using the logarithm is that when ${\rm df}_w = N$, ${\rm idf}(w)=0$, indicating that words common to all documents would be ignored. If we don't want this behavior, we can define ${\rm idf}(w)=\log\left(1+N/{\rm df}_w\right)$ or ${\rm idf}(w)=1+\log\left(N/{\rm df}_w\right)$ instead. For us, we'll not use the extra +1 for ${\rm idf}$.
#
# In the following, define a function called `get_idf(corpus, include_log=True)` that computes ${\rm idf}(w)$ for all the words in a corpus, where `corpus` for us is a processed list of bag-of-words (stemmed and lemmatized). The optional parameter `include_log` includes the logarithm in the computation.
#
# <a href="#table_of_content">back to top</a>

# %%
# compute idf
def get_idf(corpus, include_log=True):
    # TO DO
    
    all_words = set()
    for bag_of_words in corpus:
        all_words |= set(bag_of_words)
    
    word_df_dict = defaultdict(int)
    
    for word in all_words:
        for doc in corpus:
            if word in doc:
                word_df_dict[word]+=1
    
    word_idf_dict = defaultdict(float)
    for key, value in word_df_dict.items():
        word_idf_dict[key] = np.log(len(corpus)/value) if include_log else len(corpus)/value
    
    return word_idf_dict

# %% [markdown]
# You should expect to see many idf values = 0! This is by design, because we have ${\rm idf}(w)=\log N_d/{\rm df}_w$ and $N_d/{\rm df}_w=1$ for the most common words!

# %%
# test your code
idf=get_idf(corpus)
print_sorted(idf, ascending=True)
# Out:
# howev: 0.000
# identifi: 0.000
# reli: 0.000
# outsourc: 0.000
# lose: 0.069
# receiv: 0.069
# hold: 0.069
# implement: 0.069
# issu: 0.069
# compli: 0.143
# attempt: 0.143
# trebl: 0.143
# execut: 0.143
# measur: 0.143
# environment: 0.143
# difficult: 0.143
# date: 0.143
# carri: 0.143
# earn: 0.143
# often: 0.143
# histor: 0.143
# card: 0.143
# combin: 0.143
# creat: 0.143
# flexibl: 0.143
# statutori: 0.143
# place: 0.143
# ceas: 0.143
# excess: 0.143
# instabl: 0.143
# fraudul: 0.143
# advanc: 0.143
# small: 0.143
# aris: 0.143
# distribut: 0.143
# corrupt: 0.143
# septemb: 0.143
# coverag: 0.143
# commit: 0.143
# entiti: 0.143
# fulli: 0.143
# support: 0.143
# labor: 0.143
# scope: 0.143
# detect: 0.143
# describ: 0.143
# subsidiari: 0.143
# design: 0.143
# violat: 0.143
# break: 0.143
# rapid: 0.143
# question: 0.143
# balanc: 0.143
# sever: 0.143
# team: 0.143
# sensit: 0.143
# among: 0.143
# primarili: 0.143
# penalti: 0.143
# day: 0.143
# court: 0.143
# transfer: 0.143
# estat: 0.143
# case: 0.143
# might: 0.143
# shortag: 0.143
# evolv: 0.143
# appli: 0.143
# vari: 0.143
# gain: 0.143
# whole: 0.143
# enhanc: 0.143
# valuat: 0.143
# termin: 0.143
# infring: 0.143
# real: 0.143
# fair: 0.143
# impos: 0.143
# rather: 0.143
# complet: 0.143
# offic: 0.143
# public: 0.143
# contempl: 0.143
# perceiv: 0.143
# announc: 0.143
# life: 0.143
# intend: 0.143
# prevent: 0.143
# origin: 0.143
# recoveri: 0.143
# mobil: 0.143
# realiz: 0.223
# overal: 0.223
# propos: 0.223
# analysi: 0.223
# ownership: 0.223
# holiday: 0.223
# transport: 0.223
# compar: 0.223
# forward: 0.223
# hostil: 0.223
# tariff: 0.223
# renew: 0.223
# network: 0.223
# enabl: 0.223
# bank: 0.223
# compromis: 0.223
# altern: 0.223
# util: 0.223
# fee: 0.223
# establish: 0.223
# rais: 0.223
# smaller: 0.223
# concern: 0.223
# find: 0.223
# particip: 0.223
# growth: 0.223
# remain: 0.223
# provis: 0.223
# relationship: 0.223
# skill: 0.223
# physic: 0.223
# volum: 0.223
# supplier: 0.223
# prohibit: 0.223
# rule: 0.223
# institut: 0.310
# digit: 0.310
# form: 0.310
# mark: 0.310
# settl: 0.310
# channel: 0.310
# shift: 0.310
# effort: 0.310
# decis: 0.310
# contain: 0.310
# restrict: 0.310
# increment: 0.310
# matur: 0.310
# size: 0.310
# consid: 0.310
# higher: 0.310
# major: 0.310
# health: 0.310
# disclos: 0.310
# trend: 0.310
# attack: 0.310
# percentag: 0.310
# extrem: 0.310
# item: 0.310
# investig: 0.310
# greater: 0.310
# licens: 0.310
# net: 0.310
# disast: 0.310
# advertis: 0.310
# conduct: 0.310
# consider: 0.310
# legisl: 0.310
# primari: 0.310
# note: 0.310
# achiev: 0.310
# ventur: 0.310
# monetari: 0.310
# discuss: 0.310
# respons: 0.310
# matter: 0.310
# disclosur: 0.310
# sophist: 0.310
# liabl: 0.310
# year: 0.310
# tangibl: 1.609
# unreason: 1.609
# frank: 1.609
# stand: 1.609
# intermediari: 1.609
# secreci: 1.609
# grade: 1.609
# alon: 1.609
# presid: 1.609
# deduct: 1.609
# relianc: 1.609
# ask: 1.609
# unless: 1.609
# stronger: 1.609
# fitch: 1.609
# accuraci: 1.609
# transmitt: 1.609
# deceiv: 1.609
# mcx: 1.609
# bureau: 1.609
# banner: 1.609
# variabl: 1.609
# hometown: 1.609
# branch: 1.609
# optim: 1.609
# redeem: 1.609
# puerto: 1.609
# ratio: 1.609
# inclus: 1.609
# overhaul: 1.609
# telekom: 1.609
# boku: 1.609
# summer: 1.609
# payu: 1.609
# simplic: 1.609
# web: 1.609
# press: 1.609
# erron: 1.609
# later: 1.609
# gsi: 1.609
# attorney: 1.609
# deploy: 1.609
# intermitt: 1.609
# devinda: 1.609
# zepeda: 1.609
# venmo: 1.609
# widespread: 1.609
# unpaid: 1.609
# treat: 1.609
# headcount: 1.609
# lesser: 1.609
# spillov: 2.015
# best: 2.015
# broadband: 2.015
# smooth: 2.015
# geoloc: 2.015
# tapjoy: 2.015
# bolster: 2.015
# prepared: 2.015
# appendag: 2.015
# worker: 2.015
# appoint: 2.015
# spin: 2.015
# takeov: 2.015
# automobil: 2.015
# sequest: 2.015
# clariti: 2.015
# quebec: 2.015
# wire: 2.015
# quell: 2.015
# thereaft: 2.015
# ideal: 2.015
# telecheck: 2.015
# strain: 2.015
# seismic: 2.015
# creation: 2.015
# revers: 2.015
# wikileak: 2.015
# perspect: 2.015
# indefinit: 2.015
# framework: 2.015
# inapplic: 2.015
# healthi: 2.015
# shopper: 2.015
# conform: 2.015
# simpli: 2.015
# colorado: 2.015
# veloc: 2.015
# fdic: 2.015
# pan: 2.015
# ibm: 2.015
# honor: 2.015
# linkshar: 2.015
# represent: 2.015
# prescrib: 2.015
# seritag: 2.015
# counti: 2.015
# cra: 2.015
# autodesk: 2.015
# kynet: 2.015
# top: 2.015
# discoveri: 2.015
# innotrac: 2.015
# coupon: 2.015
# suspens: 2.015
# spread: 2.015
# robert: 2.015
# tenant: 2.015
# perfum: 2.015
# bliley: 2.015
# fiserv: 2.015
# harsher: 2.015
# checkfre: 2.015
# park: 2.015
# monopol: 2.015
# clearxchang: 2.015
# walmart: 2.015
# financi: 2.015
# depositori: 2.015
# gmarket: 2.015
# vero: 2.015
# exempt: 2.015
# pertain: 2.015
# leboncoin: 2.015
# spywar: 2.015
# gumtre: 2.015
# underwrit: 2.015
# congest: 2.015
# page: 2.015
# chicago: 2.015
# cssf: 2.015
# nexus: 2.015
# shorten: 2.015
# kirtsaeng: 2.015
# flier: 2.015
# justic: 2.015
# object: 2.015
# experian: 2.015
# intershop: 2.015
# bla: 2.015
# cook: 2.015
# mybank: 2.015
# acculynk: 2.015
# onto: 2.015
# cooki: 2.015
# era: 2.015
# bid: 2.015
# click: 2.015
# ambival: 2.015
# tester: 2.015
# replic: 2.015
# revok: 2.015
# schedul: 2.015
# incurr: 2.015
# suborn: 2.015
# besid: 2.015
# ticketsnow: 2.015
# true: 2.015
# simplifycommerc: 2.015
# weve: 2.015
# taiwan: 2.015
# kijiji: 2.015
# pacif: 2.015
# rightcliq: 2.015
# automot: 2.015
# slower: 2.015
# subscript: 2.015
# sentiment: 2.015
# delawar: 2.015
# baa: 2.015
# divest: 2.015
# sender: 2.015
# arguabl: 2.015
# comprehens: 2.015
# playspan: 2.015
# newli: 2.015
# stem: 2.015
# west: 2.015
# hockey: 2.015
# leaseback: 2.015
# quicker: 2.015
# croatia: 2.015
# fewer: 2.015
# daili: 2.015
# carolina: 2.015
# theori: 2.015
# japan: 2.015
# hear: 2.015
# valuabl: 2.015
# legitim: 2.015
# discrimin: 2.015
# converg: 2.015
# passiv: 2.015
# japanes: 2.015
# razorg: 2.015
# habitu: 2.015
# wpp: 2.015
# chines: 2.015
# bing: 2.015
# paynearm: 2.015
# basket: 2.015
# kimo: 2.015
# kleinanzeigen: 2.015
# master: 2.015
# flux: 2.015
# danger: 2.015
# annunci: 2.015
# propay: 2.015
# avi: 2.015
# russia: 2.015
# toward: 2.015
# concert: 2.015
# priceminist: 2.015
# morgan: 2.015
# contamin: 2.015
# popmoney: 2.015
# austrac: 2.015
# keyword: 2.015
# detail: 2.015
# argument: 2.015
# virgin: 2.015
# overturn: 2.015
# interpubl: 2.015
# omnichannel: 2.015
# nonconform: 2.015
# infosi: 2.015
# submit: 2.015
# central: 2.015
# kong: 2.015
# leach: 2.015
# prudenti: 2.015
# milo: 2.015
# surveil: 2.015
# unbox: 2.015
# stag: 2.015
# pleas: 2.015
# thief: 2.015
# promin: 2.015
# offshor: 2.015
# maximum: 2.015
# prompt: 2.015
# elavon: 2.015
# dhl: 2.015
# mode: 2.015
# still: 2.015
# ration: 2.015
# epsilon: 2.015
# recoup: 2.015
# art: 2.015
# circuit: 2.015
# publici: 2.015
# delta: 2.015
# cabl: 2.015
# comen: 2.015
# tradedoubl: 2.015
# divestitur: 2.015
# uneth: 2.015
# neighbor: 2.015
# onset: 2.015
# virtual: 2.015
# instanc: 2.015
# durat: 2.015
# mile: 2.015
# safer: 2.015
# loquo: 2.015
# exercis: 2.015
# replatform: 2.015
# cart: 2.015
# oracl: 2.015
# microsoft: 2.015
# sofortuberweisung: 2.015
# sluggish: 2.015
# cruis: 2.015
# trial: 2.015
# dvd: 2.015
# arm: 2.015
# accommod: 2.015
# congress: 2.015
# rebat: 2.015
# registr: 2.015
# investe: 2.015
# browser: 2.015
# judg: 2.015
# download: 2.015
# treasuri: 2.015
# cryptographi: 2.015
# sapient: 2.015
# soccer: 2.015
# irrespect: 2.015
# reassess: 2.015
# main: 2.015
# shoprunn: 2.015
# syke: 2.015
# unclear: 2.015
# tpp: 2.015
# train: 2.015
# zone: 2.015
# gramm: 2.015
# netspend: 2.015
# ftc: 2.015
# tradus: 2.015
# vertic: 2.015
# cosmet: 2.015
# surcharg: 2.015
# kind: 2.015
# accomplish: 2.015
# antiqu: 2.015
# occupi: 2.015
# anywher: 2.015
# forbear: 2.015
# feedback: 2.015
# suppos: 2.015
# weight: 2.708
# chair: 2.708
# craftsman: 2.708
# pendenc: 2.708
# zong: 2.708
# complementari: 2.708
# macerich: 2.708
# nonetheless: 2.708
# timelin: 2.708
# simon: 2.708
# pte: 2.708
# opt: 2.708
# bundl: 2.708
# onward: 2.708
# premis: 2.708
# mif: 2.708
# uphold: 2.708
# adob: 2.708
# exacerb: 2.708
# hill: 2.708
# snowfal: 2.708
# greec: 2.708
# cumbersom: 2.708
# golden: 2.708
# assessor: 2.708
# divis: 2.708
# hacker: 2.708
# masterpass: 2.708
# cloud: 2.708
# publish: 2.708
# sumup: 2.708
# unwilling: 2.708
# proxim: 2.708
# portal: 2.708
# occasion: 2.708
# taiwanes: 2.708
# nativ: 2.708
# implic: 2.708
# reward: 2.708
# icahn: 2.708
# journey: 2.708
# manageri: 2.708
# cooper: 2.708
# schulman: 2.708
# seq: 2.708
# grind: 2.708
# oppos: 2.708
# nbc: 2.708
# rhode: 2.708
# dutch: 2.708
# disproportion: 2.708
# judiciari: 2.708
# advis: 2.708
# bipartisan: 2.708
# navig: 2.708
# proxi: 2.708
# parliament: 2.708
# entranc: 2.708
# fma: 2.708
# rulemak: 2.708
# black: 2.708
# pool: 2.708
# dampen: 2.708
# homepag: 2.708
# certiorari: 2.708
# pci: 2.708
# synchroni: 2.708
# pictur: 2.708
# qiwi: 2.708
# donat: 2.708
# cid: 2.708
# bandwidth: 2.708
# emv: 2.708
# recruit: 2.708
# warm: 2.708
# uncommit: 2.708
# pdf: 2.708
# deni: 2.708
# statist: 2.708
# pad: 2.708
# login: 2.708
# law: 2.708
# sdks: 2.708
# oztion: 2.708
# exhibit: 2.708
# wider: 2.708
# quicksal: 2.708
# pin: 2.708
# eastern: 2.708
# core: 2.708
# dual: 2.708
# austrian: 2.708
# shopifi: 2.708
# proactiv: 2.708
# cashedg: 2.708
# precash: 2.708
# izettl: 2.708
# groupon: 2.708
# highest: 2.708
# decker: 2.708
# sdk: 2.708
# belgium: 2.708
# counteract: 2.708
# nfc: 2.708
# dan: 2.708
# bargain: 2.708
# unseason: 2.708
# dakota: 2.708
# louisiana: 2.708
# bafin: 2.708
# alloc: 2.708
# deadlin: 2.708
# dehand: 2.708
# merg: 2.708
# signal: 2.708
# committe: 2.708
# devin: 2.708
# pboc: 2.708
# rainstorm: 2.708
# viabil: 2.708
# testimoni: 2.708
# peer: 2.708
# cool: 2.708
# beacon: 2.708
# radio: 2.708
# phase: 2.708

# %% [markdown]
# <a id="compute_tf"></a>

# %% [markdown]
# ## 4. Compute tf
#
# Below we will compute ${\rm tf}(w,d)$, or the term frequency for a given word $w$, in a given document $d$. Since our ultimate goal is to compute a document vector, we'd like to keep a few things in mind
#
# 1. Store the ${\rm tf}(w, d)$ for each word in a document as a dictionary
# 2. Even when a word doesn't appear in the document $d$, we still want to keep a $0$ entry in the dictionary. This is important when we convert the dictionary to a vector, where zero entries are important
#
#
# There are multiple definitions for ${\rm tf}(w,d)$, the simplest one is
#
# $$
# {\rm tf}(w,d)=\frac{f_{w,d}}{a_d}
# $$
#
# where $f_{w,d}$ is the number of occurence of the word $w$ in the document $d$, and $a$ the average occurence of all the words in that document for normalization. Just like ${\rm idf}(w)$, a logarithm can be added
#
# $$
# {\rm tf}(w,d)=\begin{cases}
# \frac{1+\log f_{w,d}}{1+\log a_d} & f_{w,d} > 0 \\
# 0 & f_{w,d} = 0 \\
# \end{cases}
# $$
#
# Implement the function `get_df(txt, include_log=True)` that computes ${\rm tf}(w,d)$ for each word in the document (returns a defaultdict(int), so that when supplying words not in the document the dictionary will yield zero instead of an error). Also include the optional parameter `include_log` that enables the additional logarithm term in the computation. I suggest also adding a function called `_tf` that computes the function above.
#
# <a href="#table_of_content">back to top</a>

# %%
import numpy as np
from math import *

def _tf(freq, avg, include_log=True):
    # TO DO
    if include_log:
        return (1+np.log(freq))/(1+np.log(avg)) if freq > 0 else 0
    else:
        return freq/avg

def get_tf(txt, include_log=True):
    # TO DO
    bow = bag_of_words(txt)
    avg = np.mean(list(bow.values()))
    tf = defaultdict(int)
    tf = {w:_tf(f, avg, include_log) for w, f in bow.items()}
    return tf

# %%
tfs = [ get_tf(c) for c in corpus ]
print_sorted(tfs[0])
# Out:
# signific: 1.920
# compon: 1.920
# risk: 1.855
# develop: 1.855
# affect: 1.841
# price: 1.841
# subject: 1.841
# new: 1.811
# parti: 1.795
# continu: 1.761
# custom: 1.761
# third: 1.761
# advers: 1.743
# increas: 1.705
# oper: 1.705
# system: 1.684
# technolog: 1.684
# intern: 1.684
# foreign: 1.684
# sale: 1.663
# softwar: 1.663
# applic: 1.663
# manag: 1.663
# relat: 1.640
# substanti: 1.640
# limit: 1.640
# materi: 1.616
# valu: 1.616
# demand: 1.616
# addit: 1.616
# manufactur: 1.616
# experi: 1.616
# condit: 1.590
# credit: 1.590
# effect: 1.590
# partner: 1.590
# invest: 1.590
# competit: 1.590
# compet: 1.590
# econom: 1.563
# depend: 1.563
# mani: 1.563
# currenc: 1.563
# supplier: 1.563
# secur: 1.563
# margin: 1.563
# time: 1.563
# devic: 1.563
# avail: 1.563
# retail: 1.563
# content: 1.534
# distribut: 1.534
# provid: 1.534
# assur: 1.534
# inform: 1.534
# store: 1.534
# regul: 1.534
# industri: 1.503
# failur: 1.503
# obtain: 1.503
# futur: 1.503
# purchas: 1.469
# loss: 1.469
# competitor: 1.469
# intellectu: 1.469
# properti: 1.469
# certain: 1.469
# disrupt: 1.469
# jurisdict: 1.469
# trade: 1.469
# resel: 1.469
# consum: 1.432
# dollar: 1.432
# expens: 1.432
# order: 1.432
# use: 1.432
# suppli: 1.432
# term: 1.432
# licens: 1.432
# network: 1.432
# data: 1.432
# uncertainti: 1.392
# expect: 1.392
# sell: 1.392
# number: 1.392
# channel: 1.392
# abil: 1.392
# requir: 1.392
# litig: 1.392
# caus: 1.392
# carrier: 1.392
# receiv: 1.392
# global: 1.348
# perform: 1.348
# asset: 1.348
# factor: 1.348
# delay: 1.348
# rate: 1.348
# current: 1.348
# high: 1.348
# introduct: 1.348
# patent: 1.348
# infring: 1.348
# comput: 1.348
# associ: 1.348
# inventori: 1.348
# fluctuat: 1.348
# impact: 1.348
# vendor: 1.348
# reason: 1.348
# employe: 1.348
# reduc: 1.298
# access: 1.298
# event: 1.298
# amount: 1.298
# gross: 1.298
# success: 1.298
# hardwar: 1.298
# make: 1.298
# base: 1.298
# digit: 1.298
# person: 1.298
# natur: 1.298
# issu: 1.298
# agreement: 1.298
# locat: 1.298
# right: 1.298
# volatil: 1.242
# general: 1.242
# outsourc: 1.242
# exchang: 1.242
# design: 1.242
# mobil: 1.242
# offer: 1.242
# enter: 1.242
# commit: 1.242
# anticip: 1.242
# although: 1.242
# period: 1.242
# one: 1.242
# disast: 1.242
# protect: 1.242
# non: 1.242
# legal: 1.242
# revenu: 1.242
# activ: 1.242
# stock: 1.242
# strengthen: 1.177
# labor: 1.177
# improv: 1.177
# part: 1.177
# belief: 1.177
# solut: 1.177
# maintain: 1.177
# communic: 1.177
# medium: 1.177
# resourc: 1.177
# well: 1.177
# accept: 1.177
# qualiti: 1.177
# defect: 1.177
# incur: 1.177
# higher: 1.177
# arrang: 1.177
# control: 1.177
# liabil: 1.177
# health: 1.177
# claim: 1.177
# cellular: 1.177
# damag: 1.177
# outcom: 1.177
# polici: 1.177
# payment: 1.177
# declin: 1.100
# countri: 1.100
# deriv: 1.100
# instrument: 1.100
# rapid: 1.100
# unabl: 1.100
# frequent: 1.100
# lower: 1.100
# abl: 1.100
# profit: 1.100
# individu: 1.100
# exist: 1.100
# platform: 1.100
# due: 1.100
# product: 1.100
# excess: 1.100
# long: 1.100
# occur: 1.100
# practic: 1.100
# contract: 1.100
# logist: 1.100
# asia: 1.100
# warranti: 1.100
# action: 1.100
# public: 1.100
# polit: 1.100
# report: 1.100
# onlin: 1.100
# personnel: 1.100
# restrict: 1.100
# privaci: 1.100
# pii: 1.100
# account: 1.100
# card: 1.100
# quarter: 1.100
# earn: 1.100
# exposur: 1.100
# denomin: 1.100
# worldwid: 1.006
# negat: 1.006
# region: 1.006
# consolid: 1.006
# fix: 1.006
# inabl: 1.006
# impair: 1.006
# would: 1.006
# innov: 1.006
# numer: 1.006
# must: 1.006
# hold: 1.006
# seek: 1.006
# structur: 1.006
# face: 1.006
# greater: 1.006
# window: 1.006
# mac: 1.006
# transit: 1.006
# upgrad: 1.006
# circumst: 1.006
# give: 1.006
# prepay: 1.006
# typic: 1.006
# sourc: 1.006
# various: 1.006
# renew: 1.006
# decreas: 1.006
# key: 1.006
# direct: 1.006
# violat: 1.006
# distributor: 1.006
# rule: 1.006
# consid: 1.006
# major: 1.006
# reput: 1.006
# anti: 1.006
# among: 1.006
# complianc: 1.006
# procedur: 1.006
# transact: 1.006
# compromis: 1.006
# breach: 1.006
# measur: 1.006
# expos: 1.006
# oblig: 1.006
# proceed: 1.006
# spend: 0.885
# incom: 0.885
# exampl: 0.885
# sovereign: 0.885
# debt: 0.885
# europ: 0.885
# confid: 0.885
# differ: 0.885
# rais: 0.885
# outsid: 0.885
# liquid: 0.885
# vari: 0.885
# realiz: 0.885
# fair: 0.885
# govern: 0.714
# size: 0.714
# lead: 0.714
# program: 0.714
# weaken: 0.714
# segment: 0.714
# equip: 0.714
# leasehold: 0.714
# serv: 0.714
# profil: 0.714
# promot: 0.714
# brand: 0.714
# beyond: 0.714
# strategi: 0.714
# acquisit: 0.714
# inadequ: 0.714
# unexpect: 0.714
# error: 0.714
# aggreg: 0.714
# domest: 0.714
# commerc: 0.714
# telecommun: 0.714
# import: 0.714
# export: 0.714
# corrupt: 0.714
# repatri: 0.714
# extens: 0.714
# other: 0.714
# certif: 0.714
# process: 0.714
# preclud: 0.714
# inconsist: 0.714
# interpret: 0.714
# implement: 0.714
# agent: 0.714
# execut: 0.714
# interrupt: 0.714
# thus: 0.714
# accid: 0.714
# attack: 0.714
# act: 0.714
# recoveri: 0.714
# address: 0.714
# across: 0.714
# encrypt: 0.714
# unauthor: 0.714
# monitor: 0.714
# feder: 0.714
# state: 0.714
# retent: 0.714
# transfer: 0.714
# subsidiari: 0.714
# post: 0.714
# fail: 0.714
# fiscal: 0.714
# duti: 0.714
# local: 0.714
# avoid: 0.714
# offset: 0.714
# unfavor: 0.714
# equival: 0.714
# market: 0.714
# postpon: 0.422
# tighter: 0.422
# news: 0.422
# crisi: 0.422
# good: 0.422
# correspond: 0.422
# influenc: 0.422
# fuel: 0.422
# energi: 0.422
# mortgag: 0.422
# healthcar: 0.422
# macroeconom: 0.422
# behavior: 0.422
# turmoil: 0.422
# bank: 0.422
# tighten: 0.422
# insolv: 0.422
# counterparti: 0.422
# revalu: 0.422
# balanc: 0.422
# assign: 0.422
# character: 0.422
# downward: 0.422
# pressur: 0.422
# life: 0.422
# cycl: 0.422
# evolv: 0.422
# characterist: 0.422
# heavili: 0.422
# marketplac: 0.422
# near: 0.422
# entir: 0.422
# copyright: 0.422
# trademark: 0.422
# mark: 0.422
# contrast: 0.422
# emul: 0.422
# technic: 0.422
# establish: 0.422
# featur: 0.422
# altern: 0.422
# illegitim: 0.422
# breadth: 0.422
# littl: 0.422
# intensifi: 0.422
# approach: 0.422
# seamless: 0.422
# work: 0.422
# integr: 0.422
# domin: 0.422
# notabl: 0.422
# peripher: 0.422
# broader: 0.422
# instal: 0.422
# histor: 0.422
# internet: 0.422
# smaller: 0.422
# simpler: 0.422
# tradit: 0.422
# introduc: 0.422
# earli: 0.422
# stage: 0.422
# accord: 0.422
# ultim: 0.422
# becom: 0.422
# obsolet: 0.422
# accru: 0.422
# fee: 0.422
# reserv: 0.422
# review: 0.422
# live: 0.422
# facil: 0.422
# whenev: 0.422
# indic: 0.422
# recover: 0.422
# equal: 0.422
# adequ: 0.422
# unpredict: 0.422
# obsolesc: 0.422
# announc: 0.422
# consist: 0.422
# normal: 0.422
# acquir: 0.422
# combin: 0.422
# open: 0.422
# project: 0.422
# day: 0.422
# incorrect: 0.422
# produc: 0.422
# insuffici: 0.422
# firm: 0.422
# commod: 0.422
# extend: 0.422
# describ: 0.422
# achiev: 0.422
# flat: 0.422
# particip: 0.422
# rest: 0.422
# initi: 0.422
# constraint: 0.422
# yield: 0.422
# matur: 0.422
# instead: 0.422
# constrain: 0.422
# complet: 0.422
# transport: 0.422
# diminish: 0.422
# flexibl: 0.422
# respond: 0.422
# reimburs: 0.422
# adher: 0.422
# sole: 0.422
# destin: 0.422
# man: 0.422
# militari: 0.422
# itun: 0.422
# guarante: 0.422
# take: 0.422
# owner: 0.422
# usag: 0.422
# expand: 0.422
# reach: 0.422
# manner: 0.422
# propos: 0.422
# forc: 0.422
# lessen: 0.422
# piraci: 0.422
# alleg: 0.422
# monet: 0.422
# grow: 0.422
# vigor: 0.422
# defend: 0.422
# court: 0.422
# commiss: 0.422
# plaintiff: 0.422
# scope: 0.422
# valid: 0.422
# engag: 0.422
# protract: 0.422
# whether: 0.422
# pay: 0.422
# royalti: 0.422
# temporari: 0.422
# perman: 0.422
# prohibit: 0.422
# desir: 0.422
# opinion: 0.422
# least: 0.422
# accrual: 0.422
# conting: 0.422
# decis: 0.422
# buy: 0.422
# posit: 0.422
# generat: 0.422
# question: 0.422
# prospect: 0.422
# compel: 0.422
# app: 0.422
# absenc: 0.422
# keep: 0.422
# might: 0.422
# dissatisfi: 0.422
# rather: 0.422
# android: 0.422
# focus: 0.422
# suffer: 0.422
# nation: 0.422
# educ: 0.422
# enterpris: 0.422
# small: 0.422
# mid: 0.422
# iphon: 0.422
# subsid: 0.422
# subsidi: 0.422
# narrow: 0.422
# weak: 0.422
# perceiv: 0.422
# expans: 0.422
# conflict: 0.422
# discourag: 0.422
# staff: 0.422
# select: 0.422
# placement: 0.422
# display: 0.422
# stop: 0.422
# space: 0.422
# venu: 0.422
# awar: 0.422
# vehicl: 0.422
# element: 0.422
# closur: 0.422
# poor: 0.422
# termin: 0.422
# macro: 0.422
# construct: 0.422
# challeng: 0.422
# environ: 0.422
# ongo: 0.422
# present: 0.422
# origin: 0.422
# contempl: 0.422
# endeavor: 0.422
# unidentifi: 0.422
# discov: 0.422
# dilig: 0.422
# ventur: 0.422
# riski: 0.422
# problem: 0.422
# complex: 0.422
# sophist: 0.422
# bug: 0.422
# interfer: 0.422
# intend: 0.422
# outag: 0.422
# slowdown: 0.422
# detect: 0.422
# lose: 0.422
# harm: 0.422
# advertis: 0.422
# bill: 0.422
# televis: 0.422
# ownership: 0.422
# safeti: 0.422
# lock: 0.422
# mandat: 0.422
# bodi: 0.422
# test: 0.422
# modif: 0.422
# date: 0.422
# oner: 0.422
# rise: 0.422
# chief: 0.422
# offic: 0.422
# team: 0.422
# skill: 0.422
# talent: 0.422
# especi: 0.422
# silicon: 0.422
# valley: 0.422
# geopolit: 0.422
# economi: 0.422
# fire: 0.422
# nuclear: 0.422
# plant: 0.422
# terrorist: 0.422
# hostil: 0.422
# disput: 0.422
# creat: 0.422
# ineffici: 0.422
# chain: 0.422
# pandem: 0.422
# stringent: 0.422
# travel: 0.422
# freight: 0.422
# headquart: 0.422
# expenditur: 0.422
# resum: 0.422
# virus: 0.422
# physic: 0.422
# electron: 0.422
# break: 0.422
# redund: 0.422
# ineffect: 0.422
# eventu: 0.422
# prevent: 0.422
# imped: 0.422
# ship: 0.422
# deliveri: 0.422
# consequ: 0.422
# identifi: 0.422
# phone: 0.422
# email: 0.422
# contact: 0.422
# prefer: 0.422
# identif: 0.422
# malici: 0.422
# target: 0.422
# authent: 0.422
# transmiss: 0.422
# storag: 0.422
# malfeas: 0.422
# faulti: 0.422
# irregular: 0.422
# fraudul: 0.422
# induc: 0.422
# disclos: 0.422
# turn: 0.422
# help: 0.422
# unusu: 0.422
# freez: 0.422
# suspici: 0.422
# absolut: 0.422
# moreov: 0.422
# releas: 0.422
# impos: 0.422
# emerg: 0.422
# noncompli: 0.422
# concern: 0.422
# disclosur: 0.422
# websit: 0.422
# entiti: 0.422
# processor: 0.422
# liabl: 0.422
# issuer: 0.422
# fine: 0.422
# accessori: 0.422
# configur: 0.422
# indirect: 0.422
# shift: 0.422
# first: 0.422
# holiday: 0.422
# season: 0.422
# late: 0.422
# volum: 0.422
# unrel: 0.422
# reflect: 0.422
# investor: 0.422
# nevertheless: 0.422
# versus: 0.422
# tariff: 0.422
# antidump: 0.422
# primari: 0.422
# restructur: 0.422
# euro: 0.422
# convers: 0.422
# benefici: 0.422
# forward: 0.422
# option: 0.422
# place: 0.422
# recogn: 0.422
# rat: 0.422
# deterior: 0.422
# heighten: 0.422
# worsen: 0.422
# outstand: 0.422
# collater: 0.422
# insur: 0.422
# mitig: 0.422
# unsecur: 0.422
# sub: 0.422
# septemb: 0.422
# yet: 0.422
# ordinari: 0.422
# cours: 0.422
# recognit: 0.422
# consider: 0.422
# settl: 0.422
# compensatori: 0.422
# punit: 0.422
# trebl: 0.422
# monetari: 0.422
# disgorg: 0.422
# remedi: 0.422
# relief: 0.422
# statutori: 0.422
# valuat: 0.422
# defer: 0.422
# regular: 0.422
# ass: 0.422
# adequaci: 0.422

# %% [markdown]
# <a id="doc_vector"></a>

# %% [markdown]
# ## 5. Document Vector
# Combine the implementation for ${\rm tf}(w,d)$ and ${\rm idf}(w)$ to compute a word-vector for each document in a corpus. Don't forget the zero-padding that is needed when a word appears in some document but not others.
#
# Implmenet the function `get_vectors(tf,idf)`, the input is the output computed by `get_tf` and `get_idf`
#
# (*optional challenge: implement in one line!*)
#
# <a href="#table_of_content">back to top</a>

# %%
def get_vector(tf, idf):
    vector = []
    for w in idf:
        if w not in tf:
            np.insert(vector, 0)
        else:
            np.insert(vector, (tf[w]*idf[w]))
    return vector

# %%
# test your code
doc_vectors = [ get_vector(tf, idf) for tf in tfs ]

for v in doc_vectors:
    print(v)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-46-2fe668dab23e> in <module>()
#       1 # test your code
# ----> 2 doc_vectors = [ get_vector(tf, idf) for tf in tfs ]
#       3
#       4 for v in doc_vectors:
#       5     print(v)
#
# <ipython-input-46-2fe668dab23e> in <listcomp>(.0)
#       1 # test your code
# ----> 2 doc_vectors = [ get_vector(tf, idf) for tf in tfs ]
#       3
#       4 for v in doc_vectors:
#       5     print(v)
#
# <ipython-input-45-76f1e25531a0> in get_vector(tf, idf)
#       3     for w in idf:
#       4         if w not in tf:
# ----> 5             np.insert(vector, 0)
#       6         else:
#       7             np.insert(vector, (tf[w]*idf[w]))
#
# TypeError: insert() missing 1 required positional argument: 'values'

# %% [markdown]
# <a id ="similarity"></a>

# %% [markdown]
# ## 6. Similarity
#
# Given two word-vectors $\vec u$ (or $u_i$) and $\vec v$ (or $v_i$), corresponding to two documents, we want to compute different similarity metrics.
#
# 1. Cosine similarity, defined by
# $$
# {\rm Sim}_{\cos} = \frac{\vec u \cdot \vec v}{|\vec u| |\vec v|}
# $$
#
# 2. Jaccard similarity, defined by
# $$
# {\rm Sim}_{\rm Jaccard} = \frac{\sum_i \min\{u_i, v_i\}}{\sum_i \max\{u_i, v_i\}}
# $$
#
# Implement the function similarity as `sim_cis(u,v)` and `sim_jac(u,v)`. Utilize the numpy functions `numpy.linalg.norm` to compute norm of a vector and `np.dot` for computing dot-products. `np.minimum` and `np.maximum` are also useful vectorized pair-wise minimum and maximum functions.
#
# (*optional challenge: implement both functions in one line!*)
#
# <a href="#table_of_content">back to top</a>

# %%
from numpy.linalg import norm

def sim_cos(u,v):
    # TO DO
    return np.dot(u, v)/(norm(u)*norm(v))

def sim_jac(u,v):
    # TO DO
    return np.sum(np.minimum(u, v))/np.sum(np.maximum(u, v))

# %%
# test your co
# compute all the pairwise similarity metrics
size = len(doc_vectors)
matrix_cos = np.zeros((size,size))
matrix_jac = np.zeros((size,size))

for i in range(size):
    for j in range(size):
        u = doc_vectors[i]
        v = doc_vectors[j]
        matrix_cos[i][j] = sim_cos(u,v)
        matrix_jac[i][j] = sim_jac(u,v)
        
print("Cosine Similarity:")
print(matrix_cos)

print()
print("Jaccard Similarity:")
print(matrix_jac)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-40-93264cdf5e6d> in <module>()
#       1 # test your co
#       2 # compute all the pairwise similarity metrics
# ----> 3 size = len(doc_vectors)
#       4 matrix_cos = np.zeros((size,size))
#       5 matrix_jac = np.zeros((size,size))
#
# NameError: name 'doc_vectors' is not defined

# %% [markdown]
# ### Good Job! You've finished all the exercises!
#
# Here is an optional bonus challenge. We often need to debug other people's code to figure out what's wrong. It's particularly difficult when the code doesn't give errors but computes the wrong quantity. Can you describe why the following implementations for some of the exercises above may be wrong? Highlight the words at the bottom to reveal the solutions!

# %%
def get_idf_wrong(corpus, include_log=True):
    freq = defaultdict(int)
    for c in corpus:
        for w in c:
            freq[w] += 1
        
    N = len(corpus)
    if include_log:
        return { w:log(N/freq[w]) for w in freq }
    else:
        return { w:N/freq[w] for w in freq }


def get_sentiment_wrong(txt, wordlist):
    matching_words = [ w for w in wordlist if w in txt ]
    return len(matching_words)/len(txt)

def get_vectors_wrong(tf, idf):
    return np.array([ tf[w]*idf[w] for w in tf ])

# %% [markdown]
# # Solutions
#
# Drag your mouse over the white space below this cell, and you'll see details about the solutions.  Or, if it's easier, just double-click on the white space below this cell, which will reveal the cell with hidden text.  Also, please check out the file [bagofwords_solutions.py](bagofwords_solutions.py).

# %% [markdown]
# <font color="white">
# Solution
#
# get_idf: the defaultdict freq here computes the total number of occurences in all the document. We only want to count it once when a word appears in a document. This may lead to a document frequency larger than N, leading to a negative idf!
#
# get_sentiment_wrong: if a word w appears twice in the document, it won't be counted properly!
#
# get_vectors_wrong: tf may not contain all the words in idf. We need zero padding for words that appear in idf but not in tf!
# </font>
